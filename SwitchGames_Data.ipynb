# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from pathlib import Path
from collections import Counter

games_to_load = "best_selling_switch_games.csv"
switch_df = pd.read_csv(games_to_load)

switch_df
# Out:
#                                        title  copies_sold  \
# 0                        Mario Kart 8 Deluxe   48410000.0
# 1              Animal Crossing: New Horizons   40170000.0
# 2                 Super Smash Bros. Ultimate   29530000.0
# 3    The Legend of Zelda: Breath of the Wild   27790000.0
# 4                   Pokémon Sword and Shield   25370000.0
# ..                                       ...          ...
# 68                            Fitness Boxing    1000000.0
# 69     Fitness Boxing 2: Rhythm and Exercise    1000000.0
# 70                      Shin Megami Tensei V    1000000.0
# 71  Story of Seasons: Pioneers of Olive Town    1000000.0
# 72                           Thief Simulator    1000000.0
#
#                      genre                      developer  \
# 0              Kart racing                   Nintendo EPD
# 1        Social simulation                   Nintendo EPD
# 2                 Fighting  Bandai Namco StudiosSora Ltd.
# ...

# %%
switch_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         73 non-null     object
#  1   copies_sold   73 non-null     float64
#  2   genre         73 non-null     object
#  3   developer     73 non-null     object
#  4   publisher     73 non-null     object
#  5   as_of         73 non-null     object
#  6   release_date  73 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 4.1+ KB

# %%
switch_df.isnull().sum()
# Out:
# title           0
# copies_sold     0
# genre           0
# developer       0
# publisher       0
# as_of           0
# release_date    0
# dtype: int64

# %%
switch_df['copies_sold'].value_counts().sort_values()
# Out:
# 3340000.0     1
# 9430000.0     1
# 29530000.0    1
# 27790000.0    1
# 25370000.0    1
#              ..
# 1580000.0     1
# 1890000.0     2
# 1680000.0     2
# 1200000.0     2
# 1000000.0     7
# Name: copies_sold, Length: 64, dtype: int64

# %%
for col in switch_df:
    print(switch_df[col].value_counts(ascending=False), '\n')
# Out:
# Mario Kart 8 Deluxe                         1
# Metroid Dread                               1
# Big Brain Academy: Brain vs. Brain          1
# Xenoblade Chronicles: Definitive Edition    1
# Miitopia                                    1
#                                            ..
# Mario Tennis Aces                           1
# Kirby and the Forgotten Land                1
# The Legend of Zelda: Link's Awakening       1
# Nintendo Switch Sports                      1
# Thief Simulator                             1
# Name: title, Length: 73, dtype: int64
#
# 1000000.0    7
# 1200000.0    2
# 1680000.0    2
# 1890000.0    2
# 1060000.0    1
#             ..
# 4120000.0    1
# 4000000.0    1
# 3980000.0    1
# 3910000.0    1
# 3500000.0    1
# Name: copies_sold, Length: 64, dtype: int64
#
# Role-playing                        7
# Platformer                          7
# Fighting                            6
# Action role-playing                 6
# ...

# %%
switch_df.shape
# Out:
# (73, 7)

# %%
switch_df=switch_df.copy()
switch_df.drop_duplicates(subset=None,inplace=True)
switch_df.shape
# Out:
# (73, 7)
